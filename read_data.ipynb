# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('DISASTERS/1900_2021_DISASTERS.xlsx - emdat data.csv')
df2 = pd.read_csv('DISASTERS/1970-2021_DISASTERS.xlsx - emdat data.csv')

# %%
df1.columns
# Out:
# Index(['Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'Aid Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Insured Damages ('000 US$)',
#        'Total Damages ('000 US$)', 'CPI', 'Adm Level', 'Admin1 Code',
#        'Admin2 Code', 'Geo Locations'],
#       dtype='object')

# %%
df2[["Dis No","Year", "Country"]]
# Out:
#               Dis No  Year                                 Country
# 0      1970-0013-ARG  1970                               Argentina
# 1      1970-0109-AUS  1970                               Australia
# 2      1970-0044-BEN  1970                                   Benin
# 3      1970-0063-BGD  1970                              Bangladesh
# 4      1970-0026-BGD  1970                              Bangladesh
# ...              ...   ...                                     ...
# 14639  2021-0449-YEM  2021                                   Yemen
# 14640  2021-0075-ZAF  2021                            South Africa
# 14641  2021-0599-COD  2021  Congo (the Democratic Republic of the)
# 14642  2021-0020-SRB  2021                                  Serbia
# 14643  2021-0481-SSD  2021                             South Sudan
#
# [14644 rows x 3 columns]

# %%
df = pd.concat([df1, df2], axis=0)

# %%
df.columns
# Out:
# Index(['Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'Aid Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Insured Damages ('000 US$)',
#        'Total Damages ('000 US$)', 'CPI', 'Adm Level', 'Admin1 Code',
#        'Admin2 Code', 'Geo Locations', 'Dis No',
#        'Reconstruction Costs ('000 US$)'],
#       dtype='object')

# %%
df[["Insured Damages ('000 US$)", "Total Damages ('000 US$)"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30770 entries, 0 to 14643
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Insured Damages ('000 US$)  2190 non-null   float64
#  1   Total Damages ('000 US$)    10108 non-null  float64
# dtypes: float64(2)
# memory usage: 721.2 KB

# %%
df["CPI"]
# Out:
# 0        3.221647
# 1        3.221647
# 2        3.350513
# 3        3.350513
# 4        3.350513
#            ...
# 14639         NaN
# 14640         NaN
# 14641         NaN
# 14642         NaN
# 14643         NaN
# Name: CPI, Length: 30770, dtype: float64

# %%
len(df2["Reconstruction Costs (\'000 US$)"].dropna())
# Out:
# 31

# %%
df.columns
# Out:
# Index(['Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'Aid Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Insured Damages ('000 US$)',
#        'Total Damages ('000 US$)', 'CPI', 'Adm Level', 'Admin1 Code',
#        'Admin2 Code', 'Geo Locations', 'Dis No',
#        'Reconstruction Costs ('000 US$)'],
#       dtype='object')

# %%
df = df.query("Year >= 2000")

# %%
df.columns
# Out:
# Index(['Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'Aid Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Insured Damages ('000 US$)',
#        'Total Damages ('000 US$)', 'CPI', 'Adm Level', 'Admin1 Code',
#        'Admin2 Code', 'Geo Locations', 'Dis No',
#        'Reconstruction Costs ('000 US$)'],
#       dtype='object')

# %%
len(df)
# Out:
# 17914

# %%
len(df["Country"].unique())
# Out:
# 217

# %%
df["Region"]
# Out:
# 6535        Eastern Asia
# 6536       Southern Asia
# 6537       Southern Asia
# 6538       South America
# 6539       South America
#               ...
# 14639       Western Asia
# 14640    Southern Africa
# 14641      Middle Africa
# 14642    Southern Europe
# 14643    Northern Africa
# Name: Region, Length: 17914, dtype: object

# %%
df.groupby(["Region",""]).count()
# Out:
# Country
# China                             1212
# United States of America (the)    1050
# India                              742
# Philippines (the)                  670
# Indonesia                          666
#                                   ...
# Equatorial Guinea                    2
# Niue                                 2
# Tokelau                              2
# Finland                              2
# Isle of Man                          2
# Name: count, Length: 217, dtype: int64

# %%
df['Disaster Type'].unique()
# Out:
# array(['Flood', 'Drought', 'Storm', 'Epidemic', 'Landslide',
#        'Extreme temperature ', 'Wildfire', 'Insect infestation',
#        'Earthquake', 'Volcanic activity', 'Mass movement (dry)', 'Impact',
#        'Animal accident', 'Glacial lake outburst'], dtype=object)

# %%
df['Disaster Subgroup'].unique()
# Out:
# array(['Hydrological', 'Climatological', 'Meteorological', 'Biological',
#        'Geophysical', 'Extra-terrestrial'], dtype=object)

# %%
df.groupby(["Disaster Subgroup", "Disaster Type"]).count()
# Out:
#                                          Year   Seq  Glide  Disaster Group  \
# Disaster Subgroup Disaster Type
# Biological        Animal accident           2     2      0               2
#                   Epidemic               1736  1736    346            1736
#                   Insect infestation       58    58      2              58
# Climatological    Drought                 716   716    178             716
#                   Glacial lake outburst     4     4      0               4
#                   Wildfire                526   526     40             526
# Extra-terrestrial Impact                    2     2      0               2
# Geophysical       Earthquake             1174  1174    204            1174
#                   Mass movement (dry)      26    26      2              26
#                   Volcanic activity       230   230     54             230
# Hydrological      Flood                  7238  7238   1254            7238
# ...

# %%
df["Country"].value_counts()[:10]
# Out:
# Country
# China                             1212
# United States of America (the)    1050
# India                              742
# Philippines (the)                  670
# Indonesia                          666
# Viet Nam                           328
# Japan                              314
# Afghanistan                        302
# Mexico                             296
# Pakistan                           280
# Name: count, dtype: int64

# %%
df_cuted = df[df.Country.isin(df["Country"].value_counts()[:10].index)]

# %%
df_cuted.groupby(["Country", "Disaster Type"]).count()
# Out:
#                                   Year  Seq  Glide  Disaster Group  \
# Country     Disaster Type
# Afghanistan Drought                 12   12      4              12
#             Earthquake              32   32      2              32
#             Epidemic                32   32      0              32
#             Extreme temperature     10   10      2              10
#             Flood                  158  158     18             158
# ...                                ...  ...    ...             ...
# Viet Nam    Epidemic                12   12      2              12
#             Flood                  144  144     22             144
#             Landslide                8    8      0               8
#             Storm                  154  154     30             154
#             Wildfire                 2    2      0               2
#
#                                   Disaster Subgroup  Disaster Subtype  \
# Country     Disaster Type
# ...
